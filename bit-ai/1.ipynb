# %% [markdown]
# # Zajęcia 1
# ##### 3.11.2022

# %% [markdown]
# #### Machine Learning:
# - wymaga mało danych
# - jest szybki i interpretowalny
# - ma niskie wymagania techniczne
#
# Jego problem:
# - słabo radzi sobie ze złożonymi problemami
#
# #### Sieci neuronowe:
# - rozwiązują złożone problemy
# - mniej preprocessingu
# - adaptowalność i przenośność
#
# Jego problem:
# - słabo interpretowalny
#
# // Reszta na prezentacjach
